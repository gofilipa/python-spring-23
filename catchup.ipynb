# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from urllib.request import urlopen

# %%
# you can use all/part of this function to load and clean your text

def clean(url):
    # creating variables for things we need to use
    stops = stopwords.words('english')
    wordnet_lemmatizer = WordNetLemmatizer()
    
    # loading up the text
    open_url = urlopen(url)
    read_text = open_url.read()
    decoded_text = read_text.decode()
    tokens = nltk.word_tokenize(decoded_text)
    
    
    text = [] 
    for word in tokens:
        if word.isalpha(): 
            if word not in stops:
                lemma = wordnet_lemmatizer.lemmatize(word)
                text.append(word.lower())     
    
    return text

# %%
middlemarch = clean('https://www.gutenberg.org/cache/epub/145/pg145.txt')

# %%
middlemarch
# Out:
# ['project',
#  'gutenberg',
#  'ebook',
#  'middlemarch',
#  'george',
#  'eliot',
#  'this',
#  'ebook',
#  'use',
#  'anyone',
#  'anywhere',
#  'united',
#  'states',
#  'parts',
#  'world',
#  'cost',
#  'almost',
#  'restrictions',
#  'whatsoever',
#  'you',
#  'may',
#  'copy',
#  'give',
#  'away',
#  'terms',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'ebook',
#  'online',
#  'if',
#  'located',
#  'united',
#  'states',
#  'check',
#  'laws',
#  'country',
#  'located',
#  'using',
#  'ebook',
#  'title',
#  'middlemarch',
#  'author',
#  'george',
#  'eliot',
#  'release',
#  'date',
#  'july',
#  'ebook',
#  'most',
#  'recently',
#  'updated',
#  'april',
#  'language',
#  'english',
#  'start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'middlemarch',
#  'cover',
#  'middlemarch',
#  'george',
#  'eliot',
#  'new',
#  'york',
#  'boston',
#  'caldwell',
#  'company',
#  'publishers',
#  'to',
#  'dear',
#  'husband',
#  'george',
#  'henry',
#  'lewes',
#  'nineteenth',
#  'year',
#  'blessed',
#  'union',
#  'contents',
#  'prelude',
#  'book',
#  'i',
#  'miss',
#  'brooke',
#  'chapter',
#  'i',
#  'chapter',
#  'ii',
#  'chapter',
#  'iii',
#  'chapter',
#  'iv',
#  'chapter',
#  'chapter',
#  'vi',
#  'chapter',
#  'vii',
#  'chapter',
#  'viii',
#  'chapter',
#  'ix',
#  'chapter',
#  'x',
#  'chapter',
#  'xi',
#  'chapter',
#  'xii',
#  'book',
#  'ii',
#  'old',
#  'and',
#  'young',
#  'chapter',
#  'xiii',
#  'chapter',
#  'xiv',
#  'chapter',
#  'xv',
#  'chapter',
#  'xvi',
#  'chapter',
#  'xvii',
#  'chapter',
#  'xviii',
#  'chapter',
#  'xix',
#  'chapter',
#  'xx',
#  'chapter',
#  'xxi',
#  'chapter',
#  'xxii',
#  'book',
#  'iii',
#  'waiting',
#  'for',
#  'death',
#  'chapter',
#  'xxiii',
#  'chapter',
#  'xxiv',
#  'chapter',
#  'xxv',
#  'chapter',
#  'xxvi',
#  'chapter',
#  'xxvii',
#  'chapter',
#  'xxviii',
#  'chapter',
#  'xxix',
#  'chapter',
#  'xxx',
#  'chapter',
#  'xxxi',
#  'chapter',
#  'xxxii',
#  'book',
#  'iv',
#  'three',
#  'love',
#  'problems',
#  'chapter',
#  'xxxiii',
#  'chapter',
#  'xxxiv',
#  'chapter',
#  'xxxv',
#  'chapter',
#  'xxxvi',
#  'chapter',
#  'xxxvii',
#  'chapter',
#  'xxxviii',
#  'chapter',
#  'xxxix',
#  'chapter',
#  'xl',
#  'chapter',
#  'xli',
#  'chapter',
#  'xlii',
#  'chapter',
#  'xliii',
#  'book',
#  'the',
#  'dead',
#  'hand',
#  'chapter',
#  'xliv',
#  'chapter',
#  'xlv',
#  'chapter',
#  'xlvi',
#  'chapter',
#  'xlvii',
#  'chapter',
#  'xlviii',
#  'chapter',
#  'xlix',
#  'chapter',
#  'chapter',
#  'li',
#  'chapter',
#  'lii',
#  'book',
#  'vi',
#  'the',
#  'widow',
#  'and',
#  'the',
#  'wife',
#  'chapter',
#  'liii',
#  'chapter',
#  'liv',
#  'chapter',
#  'lv',
#  'chapter',
#  'lvi',
#  'chapter',
#  'lvii',
#  'chapter',
#  'lviii',
#  'chapter',
#  'lix',
#  'chapter',
#  'lx',
#  'chapter',
#  'lxi',
#  'chapter',
#  'lxii',
#  'book',
#  'vii',
#  'two',
#  'temptations',
#  'chapter',
#  'lxiii',
#  'chapter',
#  'lxiv',
#  'chapter',
#  'lxv',
#  'chapter',
#  'lxvi',
#  'chapter',
#  'lxvii',
#  'chapter',
#  'lxviii',
#  'chapter',
#  'lxix',
#  'chapter',
#  'lxx',
#  'chapter',
#  'lxxi',
#  'book',
#  'viii',
#  'sunset',
#  'and',
#  'sunrise',
#  'chapter',
#  'lxxii',
#  'chapter',
#  'lxxiii',
#  'chapter',
#  'lxxiv',
#  'chapter',
#  'lxxv',
#  'chapter',
#  'lxxvi',
#  'chapter',
#  'lxxvii',
#  'chapter',
#  'lxxviii',
#  'chapter',
#  'lxxix',
#  'chapter',
#  'lxxx',
#  'chapter',
#  'lxxxi',
#  'chapter',
#  'lxxxii',
#  'chapter',
#  'lxxxiii',
#  'chapter',
#  'lxxxiv',
#  'chapter',
#  'lxxxv',
#  'chapter',
#  'lxxxvi',
#  'finale',
#  'prelude',
#  'who',
#  'cares',
#  'much',
#  'know',
#  'history',
#  'man',
#  'mysterious',
#  'mixture',
#  'behaves',
#  'varying',
#  'experiments',
#  'time',
#  'dwelt',
#  'least',
#  'briefly',
#  'life',
#  'saint',
#  'theresa',
#  'smiled',
#  'gentleness',
#  'thought',
#  'little',
#  'girl',
#  'walking',
#  'forth',
#  'one',
#  'morning',
#  'still',
#  'smaller',
#  'brother',
#  'go',
#  'seek',
#  'martyrdom',
#  'country',
#  'moors',
#  'out',
#  'toddled',
#  'rugged',
#  'avila',
#  'two',
#  'fawns',
#  'human',
#  'hearts',
#  'already',
#  'beating',
#  'national',
#  'idea',
#  'domestic',
#  'reality',
#  'met',
#  'shape',
#  'uncles',
#  'turned',
#  'back',
#  'great',
#  'resolve',
#  'that',
#  'fit',
#  'beginning',
#  'theresa',
#  'passionate',
#  'ideal',
#  'nature',
#  'demanded',
#  'epic',
#  'life',
#  'romances',
#  'chivalry',
#  'social',
#  'conquests',
#  'brilliant',
#  'girl',
#  'her',
#  'flame',
#  'quickly',
#  'burned',
#  'light',
#  'fuel',
#  'fed',
#  'within',
#  'soared',
#  'illimitable',
#  'satisfaction',
#  'object',
#  'would',
#  'never',
#  'justify',
#  'weariness',
#  'would',
#  'reconcile',
#  'rapturous',
#  'consciousness',
#  'life',
#  'beyond',
#  'self',
#  'she',
#  'found',
#  'epos',
#  'reform',
#  'religious',
#  'order',
#  'that',
#  'spanish',
#  'woman',
#  'lived',
#  'three',
#  'hundred',
#  'years',
#  'ago',
#  'certainly',
#  'last',
#  'kind',
#  'many',
#  'theresas',
#  'born',
#  'found',
#  'epic',
#  'life',
#  'wherein',
#  'constant',
#  'unfolding',
#  'action',
#  'perhaps',
#  'life',
#  'mistakes',
#  'offspring',
#  'certain',
#  'spiritual',
#  'grandeur',
#  'meanness',
#  'opportunity',
#  'perhaps',
#  'tragic',
#  'failure',
#  'found',
#  'sacred',
#  'poet',
#  'sank',
#  'unwept',
#  'oblivion',
#  'with',
#  'dim',
#  'lights',
#  'tangled',
#  'circumstance',
#  'tried',
#  'shape',
#  'thought',
#  'deed',
#  'noble',
#  'agreement',
#  'common',
#  'eyes',
#  'struggles',
#  'seemed',
#  'mere',
#  'inconsistency',
#  'formlessness',
#  'theresas',
#  'helped',
#  'coherent',
#  'social',
#  'faith',
#  'order',
#  'could',
#  'perform',
#  'function',
#  'knowledge',
#  'ardently',
#  'willing',
#  'soul',
#  'their',
#  'ardor',
#  'alternated',
#  'vague',
#  'ideal',
#  'common',
#  'yearning',
#  'womanhood',
#  'one',
#  'disapproved',
#  'extravagance',
#  'condemned',
#  'lapse',
#  'some',
#  'felt',
#  'blundering',
#  'lives',
#  'due',
#  'inconvenient',
#  'indefiniteness',
#  'supreme',
#  'power',
#  'fashioned',
#  'natures',
#  'women',
#  'one',
#  'level',
#  'feminine',
#  'incompetence',
#  'strict',
#  'ability',
#  'count',
#  'three',
#  'social',
#  'lot',
#  'women',
#  'might',
#  'treated',
#  'scientific',
#  'certitude',
#  'meanwhile',
#  'indefiniteness',
#  'remains',
#  'limits',
#  'variation',
#  'really',
#  'much',
#  'wider',
#  'one',
#  'would',
#  'imagine',
#  'sameness',
#  'women',
#  'coiffure',
#  'favorite',
#  'prose',
#  'verse',
#  'here',
#  'cygnet',
#  'reared',
#  'uneasily',
#  'among',
#  'ducklings',
#  'brown',
#  'pond',
#  'never',
#  'finds',
#  'living',
#  'stream',
#  'fellowship',
#  'kind',
#  'here',
#  'born',
#  'saint',
#  'theresa',
#  'foundress',
#  'nothing',
#  'whose',
#  'loving',
#  'sobs',
#  'unattained',
#  'goodness',
#  'tremble',
#  'dispersed',
#  'among',
#  'hindrances',
#  'instead',
#  'centring',
#  'deed',
#  'book',
#  'i',
#  'miss',
#  'brooke',
#  'chapter',
#  'i',
#  'since',
#  'i',
#  'good',
#  'woman',
#  'reach',
#  'constantly',
#  'something',
#  'near',
#  'maid',
#  'tragedy',
#  'beaumont',
#  'and',
#  'fletcher',
#  'miss',
#  'brooke',
#  'kind',
#  'beauty',
#  'seems',
#  'thrown',
#  'relief',
#  'poor',
#  'dress',
#  'her',
#  'hand',
#  'wrist',
#  'finely',
#  'formed',
#  'could',
#  'wear',
#  'sleeves',
#  'less',
#  'bare',
#  'style',
#  'blessed',
#  'virgin',
#  'appeared',
#  'italian',
#  'painters',
#  'profile',
#  'well',
#  'stature',
#  'bearing',
#  'seemed',
#  'gain',
#  'dignity',
#  'plain',
#  'garments',
#  'side',
#  'provincial',
#  'fashion',
#  'gave',
#  'impressiveness',
#  'fine',
#  'quotation',
#  'bible',
#  'one',
#  'elder',
#  'poets',
#  'paragraph',
#  'newspaper',
#  'she',
#  'usually',
#  'spoken',
#  'remarkably',
#  'clever',
#  'addition',
#  'sister',
#  'celia',
#  'nevertheless',
#  'celia',
#  'wore',
#  'scarcely',
#  'trimmings',
#  'close',
#  'observers',
#  'dress',
#  'differed',
#  'sister',
#  'shade',
#  'coquetry',
#  'arrangements',
#  'miss',
#  'brooke',
#  'plain',
#  'dressing',
#  'due',
#  'mixed',
#  'conditions',
#  'sister',
#  'shared',
#  'the',
#  'pride',
#  'ladies',
#  'something',
#  'brooke',
#  'connections',
#  'though',
#  'exactly',
#  'aristocratic',
#  'unquestionably',
#  'good',
#  'inquired',
#  'backward',
#  'generation',
#  'two',
#  'would',
#  'find',
#  'lower',
#  'admiral',
#  'clergyman',
#  'even',
#  'ancestor',
#  'discernible',
#  'puritan',
#  'gentleman',
#  'served',
#  'cromwell',
#  'afterwards',
#  'conformed',
#  'managed',
#  'come',
#  'political',
#  'troubles',
#  'proprietor',
#  'respectable',
#  'family',
#  'estate',
#  'young',
#  'women',
#  'birth',
#  'living',
#  'quiet',
#  'attending',
#  'village',
#  'church',
#  'hardly',
#  'larger',
#  'parlor',
#  'naturally',
#  'regarded',
#  'frippery',
#  'ambition',
#  'huckster',
#  'daughter',
#  'then',
#  'economy',
#  'days',
#  'made',
#  'show',
#  'dress',
#  'first',
#  'item',
#  'deducted',
#  'margin',
#  'required',
#  'expenses',
#  'distinctive',
#  'rank',
#  'such',
#  'reasons',
#  'would',
#  'enough',
#  'account',
#  'plain',
#  'dress',
#  'quite',
#  'apart',
#  'religious',
#  'feeling',
#  'miss',
#  'brooke',
#  'case',
#  'religion',
#  'alone',
#  'would',
#  'determined',
#  'celia',
#  'mildly',
#  'acquiesced',
#  'sister',
#  'sentiments',
#  'infusing',
#  'able',
#  'accept',
#  'momentous',
#  'doctrines',
#  'without',
#  'eccentric',
#  'agitation',
#  'dorothea',
#  'knew',
#  'many',
#  'passages',
#  'pascal',
#  'pensees',
#  'jeremy',
#  'taylor',
#  'heart',
#  'destinies',
#  'mankind',
#  'seen',
#  'light',
#  'christianity',
#  'made',
#  'solicitudes',
#  'feminine',
#  'fashion',
#  'appear',
#  'occupation',
#  'bedlam',
#  'she',
#  'could',
#  'reconcile',
#  'anxieties',
#  'spiritual',
#  'life',
#  'involving',
#  'eternal',
#  'consequences',
#  'keen',
#  'interest',
#  'gimp',
#  'artificial',
#  'protrusions',
#  'drapery',
#  'her',
#  'mind',
#  'theoretic',
#  'yearned',
#  'nature',
#  'lofty',
#  'conception',
#  'world',
#  'might',
#  'frankly',
#  'include',
#  'parish',
#  'tipton',
#  'rule',
#  'conduct',
#  'enamoured',
#  'intensity',
#  'greatness',
#  'rash',
#  'embracing',
#  'whatever',
#  'seemed',
#  'aspects',
#  'likely',
#  'seek',
#  'martyrdom',
#  'make',
#  'retractations',
#  'incur',
#  'martyrdom',
#  'quarter',
#  'sought',
#  'certainly',
#  'elements',
#  'character',
#  'marriageable',
#  'girl',
#  'tended',
#  'interfere',
#  'lot',
#  'hinder',
#  'decided',
#  'according',
#  'custom',
#  'good',
#  'looks',
#  'vanity',
#  'merely',
#  'canine',
#  'affection',
#  'with',
#  'elder',
#  'sisters',
#  'yet',
#  'twenty',
#  'educated',
#  'since',
#  'twelve',
#  'years',
#  'old',
#  'lost',
#  'parents',
#  'plans',
#  'narrow',
#  'promiscuous',
#  'first',
#  'english',
#  'family',
#  'afterwards',
#  'swiss',
#  'family',
#  'lausanne',
#  'bachelor',
#  'uncle',
#  'guardian',
#  'trying',
#  'way',
#  'remedy',
#  'disadvantages',
#  'orphaned',
#  'condition',
#  'it',
#  'hardly',
#  'year',
#  'since',
#  'come',
#  'live',
#  'tipton',
#  'grange',
#  'uncle',
#  'man',
#  'nearly',
#  'sixty',
#  'acquiescent',
#  'temper',
#  'miscellaneous',
#  'opinions',
#  'uncertain',
#  'vote',
#  'he',
#  'travelled',
#  'younger',
#  'years',
#  'held',
#  'part',
#  'county',
#  'contracted',
#  'rambling',
#  'habit',
#  'mind',
#  'brooke',
#  'conclusions',
#  'difficult',
#  'predict',
#  'weather',
#  'safe',
#  'say',
#  'would',
#  'act',
#  'benevolent',
#  'intentions',
#  'would',
#  'spend',
#  'little',
#  'money',
#  'possible',
#  'carrying',
#  'for',
#  'glutinously',
#  'indefinite',
#  'minds',
#  'enclose',
#  'hard',
#  'grains',
#  'habit',
#  'man',
#  'seen',
#  'lax',
#  'interests',
#  'except',
#  'retention',
#  'concerning',
#  'watchful',
#  'suspicious',
#  'greedy',
#  'clutch',
#  'in',
#  'brooke',
#  'hereditary',
#  'strain',
#  'puritan',
#  'energy',
#  'clearly',
#  'abeyance',
#  'niece',
#  'dorothea',
#  'glowed',
#  'alike',
#  'faults',
#  'virtues',
#  'turning',
#  'sometimes',
#  'impatience',
#  'uncle',
#  'talk',
#  'way',
#  'letting',
#  'things',
#  'estate',
#  'making',
#  'long',
#  'time',
#  'would',
#  'age',
#  'command',
#  'money',
#  'generous',
#  'schemes',
#  'she',
#  'regarded',
#  'heiress',
#  'sisters',
#  'seven',
#  'hundred',
#  'parents',
#  'dorothea',
#  'married',
#  'son',
#  'son',
#  'would',
#  'inherit',
#  'brooke',
#  'estate',
#  'presumably',
#  'worth',
#  'three',
#  'thousand',
#  'rental',
#  'seemed',
#  'wealth',
#  'provincial',
#  'families',
#  'still',
#  'discussing',
#  'peel',
#  'late',
#  'conduct',
#  'catholic',
#  'question',
#  'innocent',
#  'future',
#  'gorgeous',
#  'plutocracy',
#  ...]

# %%
stops = stopwords.words('english')
wordnet_lemmatizer = WordNetLemmatizer()

# %%
open_url = urlopen('https://www.gutenberg.org/cache/epub/145/pg145.txt')
read_text = open_url.read()
decoded_text = read_text.decode()
tokens = nltk.word_tokenize(decoded_text)

# %%
tokens
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Middlemarch',
#  ',',
#  'by',
#  'George',
#  'Eliot',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  ',',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
#  'before',
#  'using',
#  'this',
#  'eBook',
#  '.',
#  'Title',
#  ':',
#  'Middlemarch',
#  'Author',
#  ':',
#  'George',
#  'Eliot',
#  'Release',
#  'Date',
#  ':',
#  'July',
#  ',',
#  '1994',
#  '[',
#  'eBook',
#  '#',
#  '145',
#  ']',
#  '[',
#  'Most',
#  'recently',
#  'updated',
#  ':',
#  'April',
#  '10',
#  ',',
#  '2023',
#  ']',
#  'Language',
#  ':',
#  'English',
#  '*',
#  '*',
#  '*',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'MIDDLEMARCH',
#  '*',
#  '*',
#  '*',
#  'cover',
#  'Middlemarch',
#  'George',
#  'Eliot',
#  'New',
#  'York',
#  'and',
#  'Boston',
#  'H.',
#  'M.',
#  'Caldwell',
#  'Company',
#  'Publishers',
#  'To',
#  'my',
#  'dear',
#  'Husband',
#  ',',
#  'George',
#  'Henry',
#  'Lewes',
#  ',',
#  'in',
#  'this',
#  'nineteenth',
#  'year',
#  'of',
#  'our',
#  'blessed',
#  'union',
#  '.',
#  'Contents',
#  'PRELUDE',
#  '.',
#  'BOOK',
#  'I',
#  '.',
#  'MISS',
#  'BROOKE',
#  '.',
#  'CHAPTER',
#  'I',
#  '.',
#  'CHAPTER',
#  'II',
#  '.',
#  'CHAPTER',
#  'III',
#  '.',
#  'CHAPTER',
#  'IV',
#  '.',
#  'CHAPTER',
#  'V.',
#  'CHAPTER',
#  'VI',
#  '.',
#  'CHAPTER',
#  'VII',
#  '.',
#  'CHAPTER',
#  'VIII',
#  '.',
#  'CHAPTER',
#  'IX',
#  '.',
#  'CHAPTER',
#  'X',
#  '.',
#  'CHAPTER',
#  'XI',
#  '.',
#  'CHAPTER',
#  'XII',
#  '.',
#  'BOOK',
#  'II',
#  '.',
#  'OLD',
#  'AND',
#  'YOUNG',
#  '.',
#  'CHAPTER',
#  'XIII',
#  '.',
#  'CHAPTER',
#  'XIV',
#  '.',
#  'CHAPTER',
#  'XV',
#  '.',
#  'CHAPTER',
#  'XVI',
#  '.',
#  'CHAPTER',
#  'XVII',
#  '.',
#  'CHAPTER',
#  'XVIII',
#  '.',
#  'CHAPTER',
#  'XIX',
#  '.',
#  'CHAPTER',
#  'XX',
#  '.',
#  'CHAPTER',
#  'XXI',
#  '.',
#  'CHAPTER',
#  'XXII',
#  '.',
#  'BOOK',
#  'III',
#  '.',
#  'WAITING',
#  'FOR',
#  'DEATH',
#  '.',
#  'CHAPTER',
#  'XXIII',
#  '.',
#  'CHAPTER',
#  'XXIV',
#  '.',
#  'CHAPTER',
#  'XXV',
#  '.',
#  'CHAPTER',
#  'XXVI',
#  '.',
#  'CHAPTER',
#  'XXVII',
#  '.',
#  'CHAPTER',
#  'XXVIII',
#  '.',
#  'CHAPTER',
#  'XXIX',
#  '.',
#  'CHAPTER',
#  'XXX',
#  '.',
#  'CHAPTER',
#  'XXXI',
#  '.',
#  'CHAPTER',
#  'XXXII',
#  '.',
#  'BOOK',
#  'IV',
#  '.',
#  'THREE',
#  'LOVE',
#  'PROBLEMS',
#  '.',
#  'CHAPTER',
#  'XXXIII',
#  '.',
#  'CHAPTER',
#  'XXXIV',
#  '.',
#  'CHAPTER',
#  'XXXV',
#  '.',
#  'CHAPTER',
#  'XXXVI',
#  '.',
#  'CHAPTER',
#  'XXXVII',
#  '.',
#  'CHAPTER',
#  'XXXVIII',
#  '.',
#  'CHAPTER',
#  'XXXIX',
#  '.',
#  'CHAPTER',
#  'XL',
#  '.',
#  'CHAPTER',
#  'XLI',
#  '.',
#  'CHAPTER',
#  'XLII',
#  '.',
#  'CHAPTER',
#  'XLIII',
#  '.',
#  'BOOK',
#  'V.',
#  'THE',
#  'DEAD',
#  'HAND',
#  '.',
#  'CHAPTER',
#  'XLIV',
#  '.',
#  'CHAPTER',
#  'XLV',
#  '.',
#  'CHAPTER',
#  'XLVI',
#  '.',
#  'CHAPTER',
#  'XLVII',
#  '.',
#  'CHAPTER',
#  'XLVIII',
#  '.',
#  'CHAPTER',
#  'XLIX',
#  '.',
#  'CHAPTER',
#  'L.',
#  'CHAPTER',
#  'LI',
#  '.',
#  'CHAPTER',
#  'LII',
#  '.',
#  'BOOK',
#  'VI',
#  '.',
#  'THE',
#  'WIDOW',
#  'AND',
#  'THE',
#  'WIFE',
#  '.',
#  'CHAPTER',
#  'LIII',
#  '.',
#  'CHAPTER',
#  'LIV',
#  '.',
#  'CHAPTER',
#  'LV',
#  '.',
#  'CHAPTER',
#  'LVI',
#  '.',
#  'CHAPTER',
#  'LVII',
#  '.',
#  'CHAPTER',
#  'LVIII',
#  '.',
#  'CHAPTER',
#  'LIX',
#  '.',
#  'CHAPTER',
#  'LX',
#  '.',
#  'CHAPTER',
#  'LXI',
#  '.',
#  'CHAPTER',
#  'LXII',
#  '.',
#  'BOOK',
#  'VII',
#  '.',
#  'TWO',
#  'TEMPTATIONS',
#  '.',
#  'CHAPTER',
#  'LXIII',
#  '.',
#  'CHAPTER',
#  'LXIV',
#  '.',
#  'CHAPTER',
#  'LXV',
#  '.',
#  'CHAPTER',
#  'LXVI',
#  '.',
#  'CHAPTER',
#  'LXVII',
#  '.',
#  'CHAPTER',
#  'LXVIII',
#  '.',
#  'CHAPTER',
#  'LXIX',
#  '.',
#  'CHAPTER',
#  'LXX',
#  '.',
#  'CHAPTER',
#  'LXXI',
#  '.',
#  'BOOK',
#  'VIII',
#  '.',
#  'SUNSET',
#  'AND',
#  'SUNRISE',
#  '.',
#  'CHAPTER',
#  'LXXII',
#  '.',
#  'CHAPTER',
#  'LXXIII',
#  '.',
#  'CHAPTER',
#  'LXXIV',
#  '.',
#  'CHAPTER',
#  'LXXV',
#  '.',
#  'CHAPTER',
#  'LXXVI',
#  '.',
#  'CHAPTER',
#  'LXXVII',
#  '.',
#  'CHAPTER',
#  'LXXVIII',
#  '.',
#  'CHAPTER',
#  'LXXIX',
#  '.',
#  'CHAPTER',
#  'LXXX',
#  '.',
#  'CHAPTER',
#  'LXXXI',
#  '.',
#  'CHAPTER',
#  'LXXXII',
#  '.',
#  'CHAPTER',
#  'LXXXIII',
#  '.',
#  'CHAPTER',
#  'LXXXIV',
#  '.',
#  'CHAPTER',
#  'LXXXV',
#  '.',
#  'CHAPTER',
#  'LXXXVI',
#  '.',
#  'FINALE',
#  '.',
#  'PRELUDE',
#  '.',
#  'Who',
#  'that',
#  'cares',
#  'much',
#  'to',
#  'know',
#  'the',
#  'history',
#  'of',
#  'man',
#  ',',
#  'and',
#  'how',
#  'the',
#  'mysterious',
#  'mixture',
#  'behaves',
#  'under',
#  'the',
#  'varying',
#  'experiments',
#  'of',
#  'Time',
#  ',',
#  'has',
#  'not',
#  'dwelt',
#  ',',
#  'at',
#  'least',
#  'briefly',
#  ',',
#  'on',
#  'the',
#  'life',
#  'of',
#  'Saint',
#  'Theresa',
#  ',',
#  'has',
#  'not',
#  'smiled',
#  'with',
#  'some',
#  'gentleness',
#  'at',
#  'the',
#  'thought',
#  'of',
#  'the',
#  'little',
#  'girl',
#  'walking',
#  'forth',
#  'one',
#  'morning',
#  'hand-in-hand',
#  'with',
#  'her',
#  'still',
#  'smaller',
#  'brother',
#  ',',
#  'to',
#  'go',
#  'and',
#  'seek',
#  'martyrdom',
#  'in',
#  'the',
#  'country',
#  'of',
#  'the',
#  'Moors',
#  '?',
#  'Out',
#  'they',
#  'toddled',
#  'from',
#  'rugged',
#  'Avila',
#  ',',
#  'wide-eyed',
#  'and',
#  'helpless-looking',
#  'as',
#  'two',
#  'fawns',
#  ',',
#  'but',
#  'with',
#  'human',
#  'hearts',
#  ',',
#  'already',
#  'beating',
#  'to',
#  'a',
#  'national',
#  'idea',
#  ';',
#  'until',
#  'domestic',
#  'reality',
#  'met',
#  'them',
#  'in',
#  'the',
#  'shape',
#  'of',
#  'uncles',
#  ',',
#  'and',
#  'turned',
#  'them',
#  'back',
#  'from',
#  'their',
#  'great',
#  'resolve',
#  '.',
#  'That',
#  'child-pilgrimage',
#  'was',
#  'a',
#  'fit',
#  'beginning',
#  '.',
#  'Theresa',
#  '’',
#  's',
#  'passionate',
#  ',',
#  'ideal',
#  'nature',
#  'demanded',
#  'an',
#  'epic',
#  'life',
#  ':',
#  'what',
#  'were',
#  'many-volumed',
#  'romances',
#  'of',
#  'chivalry',
#  'and',
#  'the',
#  'social',
#  'conquests',
#  'of',
#  'a',
#  'brilliant',
#  'girl',
#  'to',
#  'her',
#  '?',
#  'Her',
#  'flame',
#  'quickly',
#  'burned',
#  'up',
#  'that',
#  'light',
#  'fuel',
#  ';',
#  'and',
#  ',',
#  'fed',
#  'from',
#  'within',
#  ',',
#  'soared',
#  'after',
#  'some',
#  'illimitable',
#  'satisfaction',
#  ',',
#  'some',
#  'object',
#  'which',
#  'would',
#  'never',
#  'justify',
#  'weariness',
#  ',',
#  'which',
#  'would',
#  'reconcile',
#  'self-despair',
#  'with',
#  'the',
#  'rapturous',
#  'consciousness',
#  'of',
#  'life',
#  'beyond',
#  'self',
#  '.',
#  'She',
#  'found',
#  'her',
#  'epos',
#  'in',
#  'the',
#  'reform',
#  'of',
#  'a',
#  'religious',
#  'order',
#  '.',
#  'That',
#  'Spanish',
#  'woman',
#  'who',
#  'lived',
#  'three',
#  'hundred',
#  'years',
#  'ago',
#  ',',
#  'was',
#  'certainly',
#  'not',
#  'the',
#  'last',
#  'of',
#  'her',
#  'kind',
#  '.',
#  'Many',
#  'Theresas',
#  'have',
#  'been',
#  'born',
#  'who',
#  'found',
#  'for',
#  'themselves',
#  'no',
#  'epic',
#  'life',
#  'wherein',
#  'there',
#  'was',
#  'a',
#  'constant',
#  'unfolding',
#  'of',
#  'far-resonant',
#  'action',
#  ';',
#  'perhaps',
#  'only',
#  'a',
#  'life',
#  'of',
#  'mistakes',
#  ',',
#  'the',
#  'offspring',
#  'of',
#  'a',
#  'certain',
#  'spiritual',
#  'grandeur',
#  'ill-matched',
#  'with',
#  'the',
#  'meanness',
#  'of',
#  'opportunity',
#  ';',
#  'perhaps',
#  'a',
#  'tragic',
#  'failure',
#  'which',
#  'found',
#  'no',
#  'sacred',
#  'poet',
#  'and',
#  'sank',
#  'unwept',
#  'into',
#  'oblivion',
#  '.',
#  'With',
#  'dim',
#  'lights',
#  'and',
#  'tangled',
#  'circumstance',
#  'they',
#  'tried',
#  'to',
#  'shape',
#  'their',
#  'thought',
#  'and',
#  'deed',
#  'in',
#  'noble',
#  'agreement',
#  ';',
#  'but',
#  'after',
#  'all',
#  ',',
#  'to',
#  'common',
#  'eyes',
#  'their',
#  'struggles',
#  'seemed',
#  'mere',
#  'inconsistency',
#  'and',
#  'formlessness',
#  ';',
#  'for',
#  'these',
#  'later-born',
#  'Theresas',
#  'were',
#  'helped',
#  'by',
#  'no',
#  'coherent',
#  'social',
#  'faith',
#  'and',
#  'order',
#  'which',
#  'could',
#  'perform',
#  'the',
#  'function',
#  'of',
#  'knowledge',
#  'for',
#  'the',
#  'ardently',
#  'willing',
#  'soul',
#  '.',
#  'Their',
#  'ardor',
#  'alternated',
#  'between',
#  'a',
#  'vague',
#  'ideal',
#  'and',
#  'the',
#  'common',
#  'yearning',
#  'of',
#  'womanhood',
#  ';',
#  'so',
#  'that',
#  'the',
#  'one',
#  'was',
#  'disapproved',
#  'as',
#  'extravagance',
#  ',',
#  'and',
#  'the',
#  'other',
#  'condemned',
#  'as',
#  'a',
#  'lapse',
#  '.',
#  'Some',
#  'have',
#  'felt',
#  'that',
#  'these',
#  'blundering',
#  'lives',
#  'are',
#  'due',
#  'to',
#  'the',
#  'inconvenient',
#  'indefiniteness',
#  'with',
#  'which',
#  'the',
#  'Supreme',
#  'Power',
#  'has',
#  'fashioned',
#  'the',
#  'natures',
#  'of',
#  'women',
#  ':',
#  'if',
#  'there',
#  'were',
#  'one',
#  'level',
#  'of',
#  'feminine',
#  'incompetence',
#  'as',
#  'strict',
#  'as',
#  'the',
#  'ability',
#  'to',
#  'count',
#  'three',
#  'and',
#  'no',
#  'more',
#  ',',
#  'the',
#  'social',
#  'lot',
#  'of',
#  'women',
#  'might',
#  'be',
#  'treated',
#  'with',
#  'scientific',
#  'certitude',
#  '.',
#  'Meanwhile',
#  'the',
#  'indefiniteness',
#  'remains',
#  ',',
#  'and',
#  'the',
#  'limits',
#  'of',
#  'variation',
#  'are',
#  'really',
#  'much',
#  'wider',
#  'than',
#  'any',
#  'one',
#  'would',
#  'imagine',
#  'from',
#  'the',
#  'sameness',
#  'of',
#  'women',
#  '’',
#  's',
#  'coiffure',
#  'and',
#  'the',
#  'favorite',
#  'love-stories',
#  'in',
#  'prose',
#  'and',
#  'verse',
#  '.',
#  'Here',
#  'and',
#  'there',
#  'a',
#  'cygnet',
#  'is',
#  'reared',
#  'uneasily',
#  'among',
#  'the',
#  'ducklings',
#  'in',
#  'the',
#  'brown',
#  'pond',
#  ',',
#  'and',
#  'never',
#  'finds',
#  'the',
#  'living',
#  'stream',
#  'in',
#  'fellowship',
#  'with',
#  'its',
#  'own',
#  'oary-footed',
#  'kind',
#  '.',
#  'Here',
#  'and',
#  'there',
#  'is',
#  'born',
#  'a',
#  'Saint',
#  'Theresa',
#  ',',
#  ...]

# %%
text = [] 
for word in tokens:
    if word.isalpha():
        if word not in stops:
            lemma = wordnet_lemmatizer.lemmatize(word)
            text.append(lemma.lower())

# %%
len(set(text))
# Out:
# 13379

# %%
len(text)
# Out:
# 157054
